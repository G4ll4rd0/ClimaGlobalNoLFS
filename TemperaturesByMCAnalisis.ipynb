# %% [markdown]
# # Proyecto Clima En Ciudades Mayores
# - Contreras Figueroa, Javier Alejandro
# - Gallardo Vázquez, Rafael
# - Juárez Badillo Chavez, Rafael

# %%
import os
import time
import phik
import pandas as pd
import numpy as np
import seaborn as sns
import geopandas as gpd
import matplotlib.pyplot as plt

from phik.report import plot_correlation_matrix
from shapely.geometry import Point
from geopandas import GeoDataFrame
from lat_lon_parser import parse

basedir = './GlobalTemperatures'

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Carga de Datos

# %%
clima = os.path.join(basedir, 'GlobalLandTemperaturesbyMajorCity' + '.csv')
dfClima = pd.read_csv(clima)
df = dfClima.copy()
df
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty  \
# 0       1849-01-01              26.704                          1.435
# 1       1849-02-01              27.434                          1.362
# 2       1849-03-01              28.101                          1.612
# 3       1849-04-01              26.140                          1.387
# 4       1849-05-01              25.427                          1.200
# ...            ...                 ...                            ...
# 239172  2013-05-01              18.979                          0.807
# 239173  2013-06-01              23.522                          0.647
# 239174  2013-07-01              25.251                          1.042
# 239175  2013-08-01              24.528                          0.840
# 239176  2013-09-01                 NaN                            NaN
#
#            City        Country Latitude Longitude
# 0       Abidjan  Côte D'Ivoire    5.63N     3.23W
# 1       Abidjan  Côte D'Ivoire    5.63N     3.23W
# 2       Abidjan  Côte D'Ivoire    5.63N     3.23W
# 3       Abidjan  Côte D'Ivoire    5.63N     3.23W
# 4       Abidjan  Côte D'Ivoire    5.63N     3.23W
# ...         ...            ...      ...       ...
# 239172     Xian          China   34.56N   108.97E
# 239173     Xian          China   34.56N   108.97E
# 239174     Xian          China   34.56N   108.97E
# 239175     Xian          China   34.56N   108.97E
# 239176     Xian          China   34.56N   108.97E
#
# [239177 rows x 7 columns]

# %% [markdown]
# Nos damos cuenta que nuestra variable dt es un objeto en vez de una fecha, por lo que la convertiremos para poder calcular la temporada del año

# %%
dfClima.dtypes
# Out:
# dt                                object
# AverageTemperature               float64
# AverageTemperatureUncertainty    float64
# City                              object
# Country                           object
# Latitude                          object
# Longitude                         object
# dtype: object

# %%
df['dt'] = pd.to_datetime(dfClima['dt'])
df.dtypes, display(df)
# Out:
#                dt  AverageTemperature  AverageTemperatureUncertainty     City  \
# 0      1849-01-01              26.704                          1.435  Abidjan
# 1      1849-02-01              27.434                          1.362  Abidjan
# 2      1849-03-01              28.101                          1.612  Abidjan
# 3      1849-04-01              26.140                          1.387  Abidjan
# 4      1849-05-01              25.427                          1.200  Abidjan
# ...           ...                 ...                            ...      ...
# 239172 2013-05-01              18.979                          0.807     Xian
# 239173 2013-06-01              23.522                          0.647     Xian
# 239174 2013-07-01              25.251                          1.042     Xian
# 239175 2013-08-01              24.528                          0.840     Xian
# 239176 2013-09-01                 NaN                            NaN     Xian
#
#               Country Latitude Longitude
# 0       Côte D'Ivoire    5.63N     3.23W
# 1       Côte D'Ivoire    5.63N     3.23W
# 2       Côte D'Ivoire    5.63N     3.23W
# 3       Côte D'Ivoire    5.63N     3.23W
# 4       Côte D'Ivoire    5.63N     3.23W
# ...               ...      ...       ...
# 239172          China   34.56N   108.97E
# 239173          China   34.56N   108.97E
# 239174          China   34.56N   108.97E
# 239175          China   34.56N   108.97E
# 239176          China   34.56N   108.97E
#
# [239177 rows x 7 columns]
# (dt                               datetime64[ns]
#  AverageTemperature                      float64
#  AverageTemperatureUncertainty           float64
#  City                                     object
#  Country                                  object
#  Latitude                                 object
#  Longitude                                object
#  dtype: object,
#  None)

# %% [markdown]
# Una vez que ya lo poseemos como algo de clase fecha es cuando sacaremos el mes para luego reemplazarlo por la temporada

# %%
df['Season'] = pd.DatetimeIndex(df['dt']).month
df
# Out:
#                dt  AverageTemperature  AverageTemperatureUncertainty     City  \
# 0      1849-01-01              26.704                          1.435  Abidjan
# 1      1849-02-01              27.434                          1.362  Abidjan
# 2      1849-03-01              28.101                          1.612  Abidjan
# 3      1849-04-01              26.140                          1.387  Abidjan
# 4      1849-05-01              25.427                          1.200  Abidjan
# ...           ...                 ...                            ...      ...
# 239172 2013-05-01              18.979                          0.807     Xian
# 239173 2013-06-01              23.522                          0.647     Xian
# 239174 2013-07-01              25.251                          1.042     Xian
# 239175 2013-08-01              24.528                          0.840     Xian
# 239176 2013-09-01                 NaN                            NaN     Xian
#
#               Country Latitude Longitude  Season
# 0       Côte D'Ivoire    5.63N     3.23W       1
# 1       Côte D'Ivoire    5.63N     3.23W       2
# 2       Côte D'Ivoire    5.63N     3.23W       3
# 3       Côte D'Ivoire    5.63N     3.23W       4
# 4       Côte D'Ivoire    5.63N     3.23W       5
# ...               ...      ...       ...     ...
# 239172          China   34.56N   108.97E       5
# 239173          China   34.56N   108.97E       6
# 239174          China   34.56N   108.97E       7
# 239175          China   34.56N   108.97E       8
# 239176          China   34.56N   108.97E       9
#
# [239177 rows x 8 columns]

# %% [markdown]
# Usamos un diccionario de valores para reemplazar los valores de los meses por las temporadas

# %%
df['Latitude'] = df['Latitude'].apply(lambda x:  parse(x))
df['Longitude'] = df['Longitude'].apply(lambda x: parse(x))
df['Hemisferio'] = np.where(df['Latitude'] >= 0, 'Norte', 'Sur')
df.dropna(inplace = True)
df.drop(['AverageTemperatureUncertainty'], axis = 1, inplace = True)

df['Season'] = np.where(
    df['Hemisferio'] == 'Norte', 
        np.where(df['Season'] <= 3, 'Invierno', 
        np.where(df['Season'] <= 6, 'Primavera', 
        np.where(df['Season'] <= 9, 'Verano', 'Otoño'))),
    # Sur
        np.where(df['Season'] <= 3, 'Verano', 
        np.where(df['Season'] <= 6, 'Otoño', 
        np.where(df['Season'] <= 9, 'Invierno', 'Primavera'))))

df
# Out:
#                dt  AverageTemperature     City        Country  Latitude  \
# 0      1849-01-01              26.704  Abidjan  Côte D'Ivoire      5.63
# 1      1849-02-01              27.434  Abidjan  Côte D'Ivoire      5.63
# 2      1849-03-01              28.101  Abidjan  Côte D'Ivoire      5.63
# 3      1849-04-01              26.140  Abidjan  Côte D'Ivoire      5.63
# 4      1849-05-01              25.427  Abidjan  Côte D'Ivoire      5.63
# ...           ...                 ...      ...            ...       ...
# 239171 2013-04-01              12.563     Xian          China     34.56
# 239172 2013-05-01              18.979     Xian          China     34.56
# 239173 2013-06-01              23.522     Xian          China     34.56
# 239174 2013-07-01              25.251     Xian          China     34.56
# 239175 2013-08-01              24.528     Xian          China     34.56
#
#         Longitude     Season Hemisferio
# 0           -3.23   Invierno      Norte
# 1           -3.23   Invierno      Norte
# 2           -3.23   Invierno      Norte
# 3           -3.23  Primavera      Norte
# 4           -3.23  Primavera      Norte
# ...           ...        ...        ...
# 239171     108.97  Primavera      Norte
# 239172     108.97  Primavera      Norte
# 239173     108.97  Primavera      Norte
# 239174     108.97     Verano      Norte
# 239175     108.97     Verano      Norte
#
# [228175 rows x 8 columns]

# %% [markdown]
# Ya teniendo este archivo lo guardamos como csv para usarlo posteriormente

# %%
# Esta linea ya se corrio una vez, se queda por documentación
#df.to_csv(os.path.join(basedir, 'GLTbyMC_corrected.csv'), index = False)

# %% [markdown]
# ## Comprensión de negocio y datos

# %% [markdown]
# Como podemos ver, estos datos seran datos de panel, ya que son varios sujetos a lo largo del tiempo

# %%
filename = 'GLTbyMC_corrected.csv'
filepath  = os.path.join(basedir, filename)
data = pd.read_csv(filepath)
data['dt'] = pd.to_datetime(data['dt'])
data
# Out:
#                dt  AverageTemperature     City        Country  Latitude  \
# 0      1849-01-01              26.704  Abidjan  Côte D'Ivoire      5.63
# 1      1849-02-01              27.434  Abidjan  Côte D'Ivoire      5.63
# 2      1849-03-01              28.101  Abidjan  Côte D'Ivoire      5.63
# 3      1849-04-01              26.140  Abidjan  Côte D'Ivoire      5.63
# 4      1849-05-01              25.427  Abidjan  Côte D'Ivoire      5.63
# ...           ...                 ...      ...            ...       ...
# 228170 2013-04-01              12.563     Xian          China     34.56
# 228171 2013-05-01              18.979     Xian          China     34.56
# 228172 2013-06-01              23.522     Xian          China     34.56
# 228173 2013-07-01              25.251     Xian          China     34.56
# 228174 2013-08-01              24.528     Xian          China     34.56
#
#         Longitude     Season Hemisferio
# 0           -3.23   Invierno      Norte
# 1           -3.23   Invierno      Norte
# 2           -3.23   Invierno      Norte
# 3           -3.23  Primavera      Norte
# 4           -3.23  Primavera      Norte
# ...           ...        ...        ...
# 228170     108.97  Primavera      Norte
# 228171     108.97  Primavera      Norte
# 228172     108.97  Primavera      Norte
# 228173     108.97     Verano      Norte
# 228174     108.97     Verano      Norte
#
# [228175 rows x 8 columns]

# %% [markdown]
# También vemos que no tenemos nulos en nuestro dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 228175 entries, 0 to 228174
# Data columns (total 8 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   dt                  228175 non-null  datetime64[ns]
#  1   AverageTemperature  228175 non-null  float64
#  2   City                228175 non-null  object
#  3   Country             228175 non-null  object
#  4   Latitude            228175 non-null  float64
#  5   Longitude           228175 non-null  float64
#  6   Season              228175 non-null  object
#  7   Hemisferio          228175 non-null  object
# dtypes: datetime64[ns](1), float64(3), object(4)
# memory usage: 13.9+ MB

# %% [markdown]
# Posteriormente realizamos una tabla para ver de mejor manera las variables de nuestro dataset

# %%
dt = ['dt', 'Análisis', 'caracteres', 'intervalo', 'datetime', 'Entre 1743-11-01 y 2013-09-01', 'Cambio de la temperatura a lo largo de los años']
at = ['AverageTemperature', 'Observación', 'numeros', 'de razón', 'float64', 'Cualquiera en la escala Celsius', 'NA']
city = ['City', 'Análisis', 'caracteres', 'nominales', 'object', 'Cualquier ciudad', 'Cambio de la temperatura en distintas ciudades']
country = ['Country', 'Análisis', 'caracteres', 'nominales', 'object', 'Paises del mundo', 'Cambio de la temperatura agrupando por pais']
lt = ['Latitude', '', 'numeros', 'intervalo', 'float64', 'de -90 a 90', 'Se puede analizar por zona del mundo o para hacer mapas']
ln = ['Longitude', '', 'numeros', 'intervalo', 'float64', 'de -180 a 180', 'Se puede analizar por zona del mundo o para hacer mapas']
ss = ['Season', 'Análisis', 'caracteres', 'nominales', 'object', 'Primavera/Verano/Otoño/Invierno', 'Cambio de temperatura por epoca del año']

listaDatos = [dt, at, city, country, lt, ln, ss]

explicacion = pd.DataFrame(listaDatos, columns=['Columna', 'Unidad de:', 'Tipo csv', 'Tipo de dato', 'Tipo en python', 'Valores válidos', 'Pregunta a responder'])
explicacion
# Out:
#               Columna   Unidad de:    Tipo csv Tipo de dato Tipo en python  \
# 0                  dt     Análisis  caracteres    intervalo       datetime
# 1  AverageTemperature  Observación     numeros     de razón        float64
# 2                City     Análisis  caracteres    nominales         object
# 3             Country     Análisis  caracteres    nominales         object
# 4            Latitude                  numeros    intervalo        float64
# 5           Longitude                  numeros    intervalo        float64
# 6              Season     Análisis  caracteres    nominales         object
#
#                    Valores válidos  \
# 0    Entre 1743-11-01 y 2013-09-01
# 1  Cualquiera en la escala Celsius
# 2                 Cualquier ciudad
# 3                 Paises del mundo
# 4                      de -90 a 90
# 5                    de -180 a 180
# 6  Primavera/Verano/Otoño/Invierno
#
#                                 Pregunta a responder
# 0    Cambio de la temperatura a lo largo de los años
# 1                                                 NA
# 2     Cambio de la temperatura en distintas ciudades
# 3        Cambio de la temperatura agrupando por pais
# 4  Se puede analizar por zona del mundo o para ha...
# 5  Se puede analizar por zona del mundo o para ha...
# 6            Cambio de temperatura por epoca del año

# %% [markdown]
# ## Análisis Univariado

# %% [markdown]
# #### Latitud y Longitud
# Cargamos un mapa del mundo para observar donde estan nuestras ciudades a analizar
# Vemos que estan distribuidas a lo largo del mundo, con una concentración en la zona de India y China

# %%
geometry = [Point(xy) for xy in zip(data['Longitude'], data['Latitude'])]
gdf = GeoDataFrame(data, geometry=geometry)

#this is a simple map that goes with geopandas
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
gdf.plot(ax=world.plot(figsize=(10, 6)), marker='o', color='red', markersize=15)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Temperaturas
# - La mayoria de las temperaturas están entre 10 y 30 grados con la mayor concentración dandose despues de los 20
# - Cualquier temperatura abajo de ~7° es considerada como outlier

# %%
fig, ax = plt.subplots(nrows=2, ncols=1,figsize=(22,6))

plt.subplot(1, 2, 1)
sns.boxplot(x= data['AverageTemperature'])

plt.subplot(1, 2, 2)
sns.distplot(x = data['AverageTemperature'], kde= True, bins=100)
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# #### Fechas
# Se castea como valor para poder ver los graficos, más adelante se evalua como categorica
# - Las fechas más antiguas tienen menos datos, al igual que la más reciente

# %%
fig, ax = plt.subplots(nrows=2, ncols=1,figsize=(22,6))

plt.subplot(1, 2, 1)
sns.boxplot(x = data['dt'].apply(lambda x: x.value))

plt.subplot(1, 2, 2)
sns.distplot(x = data['dt'].apply(lambda x: x.value), kde= True, bins=100)
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# #### Ciudad / País / Temporada / Fechas
# - Como ya veiamos en el mapa tenemos muchas ciudades y también paises
# - Las temporadas son las 4 que conocemos
# - No todas las ciudades poseen la misma cantidad de registros, hay unas con menos y otras con más
# - Los dos paises que tienen mas datos son India y China, cada uno con ~15% de los datos
# - El país con menos datos es peru, que solo tiene a Lima y tiene ~0.6% de los datos totales
# - Las temporadas se encuentran distribuidas de manera uniforme
# - Las fechas no poseen todas la misma cantidad de registro, teniendo las menores cantidades en los años mas antiguos y el mas reciente en el dataset que es el 2013

# %%
nom_cats = ['City','Country','Season', 'dt']

for col in nom_cats:

    print('Variable: ', col)
    x = len(data[col].unique())
    if x > 15:
        print(f'Variable de alta cardinalidad. {x} valores')
    else:
        print(f'Variable de baja cardinalidad. {x} valores')
    print(data[col].value_counts(sort=True,normalize=True))
    print('')
    print('')
# Out:
# Variable:  City
# Variable de alta cardinalidad. 100 valores
# Madrid              0.013875
# Berlin              0.013875
# London              0.013875
# Saint Petersburg    0.013875
# Rome                0.013875
#                       ...
# Addis Abeba         0.007358
# Nairobi             0.007354
# Fortaleza           0.007271
# Dar Es Salaam       0.006951
# Lima                0.006666
# Name: City, Length: 100, dtype: float64
#
#
# Variable:  Country
# Variable de alta cardinalidad. 49 valores
# China                                 0.153181
# India                                 0.151756
# Brazil                                0.053200
# Turkey                                0.040491
# United States                         0.036099
# Egypt                                 0.033089
# Pakistan                              0.028443
# Russia                                0.027751
# Canada                                0.027531
# Nigeria                               0.022790
# Australia                             0.018135
# Japan                                 0.017750
# Colombia                              0.017544
# Saudi Arabia                          0.016899
# Indonesia                             0.016470
# South Africa                          0.016417
# Spain                                 0.013875
# Italy                                 0.013875
# Germany                               0.013875
# United Kingdom                        0.013875
# Ukraine                               0.013875
# France                                0.013875
# Morocco                               0.012771
# Burma                                 0.011097
# Bangladesh                            0.011097
# Syria                                 0.010864
# Iraq                                  0.010168
# Thailand                              0.009843
# Dominican Republic                    0.009672
# Iran                                  0.009445
# Mexico                                0.009401
# Afghanistan                           0.009295
# South Korea                           0.009186
# Taiwan                                0.009076
# Vietnam                               0.009068
# Singapore                             0.008993
# Philippines                           0.008857
# Chile                                 0.008327
# Senegal                               0.008204
# Côte D'Ivoire                         0.007788
# Sudan                                 0.007748
# Angola                                0.007604
# Congo (Democratic Republic Of The)    0.007604
# Zimbabwe                              0.007407
# Somalia                               0.007358
# Ethiopia                              0.007358
# Kenya                                 0.007354
# Tanzania                              0.006951
# Peru                                  0.006666
# Name: Country, dtype: float64
#
#
# Variable:  Season
# Variable de baja cardinalidad. 4 valores
# Invierno     0.250347
# Verano       0.250343
# Primavera    0.249690
# Otoño        0.249620
# Name: Season, dtype: float64
#
#
# Variable:  dt
# Variable de alta cardinalidad. 3167 valores
# 1997-07-01    0.000438
# 1964-01-01    0.000438
# 1964-12-01    0.000438
# 1964-11-01    0.000438
# 1964-10-01    0.000438
#                 ...
# 1754-11-01    0.000044
# 1762-08-01    0.000044
# 1762-01-01    0.000044
# 1761-10-01    0.000044
# 2013-09-01    0.000031
# Name: dt, Length: 3167, dtype: float64

# %% [markdown]
# ## Análisis Bivariado

# %% [markdown]
# #### Correlaciones
# Lo primero que hacemos es crear una lista que no tenga la columna de geometría para realizar el calculo de la correlación phik

# %%
columnList = data.columns.to_list()
columnList.remove('geometry')
columnList.remove('Latitude')
columnList.remove('Longitude')
columnList
# Out:
# ['dt', 'AverageTemperature', 'City', 'Country', 'Season', 'Hemisferio']

# %%
phik_overview = data[columnList].phik_matrix(interval_cols=['AverageTemperature'])
plot_correlation_matrix(phik_overview.values,
                        x_labels=phik_overview.columns,
                        y_labels=phik_overview.index,
                        vmin=0, vmax=1, color_map="Greens",
                        title=r"correlation $\phi_K$",
                        fontsize_factor=1.5,
                        figsize=(10, 8))
plt.tight_layout()

# %% [markdown]
# #### Ciudades por País

# %%
data.groupby('Country')['City'].nunique().sort_values(ascending = False).plot(kind = 'bar', figsize = (10, 10))
# Out:
# <AxesSubplot:xlabel='Country'>

# %% [markdown]
# #### Cambio de Temperatura en algunas Ciudades

# %%
# TODO: check if each year has every month
cityList = ['Mexico', 'Shanghai', 'New York', 'New Delhi', 'Sydney']

for city in cityList:
    tempData = data.loc[data.City == city]
    tempData['Year'] = pd.DatetimeIndex(tempData['dt']).year
    graphData = tempData.groupby('Year')['AverageTemperature'].mean().reset_index()
    temperature_px = graphData['AverageTemperature']
    graphData['10'] = temperature_px.rolling(window=10).mean()

    graphData.set_index('Year', inplace = True)

    print(f'Ciudad: {city}')
    display(graphData)

    plt.figure(figsize=(18,10))
    ax = plt.subplot()
    ax.plot(graphData['AverageTemperature'], alpha=0.8, label='average temperature')
    ax.plot(graphData['10'], color="orange", label='10-year average temperature')
    plt.xlabel('Years')
    plt.ylabel('Temperature (in °C)')
    plt.title(f'Temperatura por año en {city}', fontsize = 20)
    plt.grid()
    plt.legend()
    plt.show()
    plt.clf()
# Out:
# Ciudad: Mexico
#       AverageTemperature         10
# Year
# 1835           14.098083        NaN
# 1836           14.803000        NaN
# 1837           14.822583        NaN
# 1838           14.480333        NaN
# 1839           14.907333        NaN
# ...                  ...        ...
# 2009           16.653667  16.364558
# 2010           15.873083  16.340475
# 2011           16.639167  16.406508
# 2012           16.426500  16.412158
# 2013           17.342444  16.481294
#
# [179 rows x 2 columns]
# Ciudad: Shanghai
#       AverageTemperature         10
# Year
# 1841           14.869583        NaN
# 1842           15.427667        NaN
# 1843           15.528833        NaN
# 1844           15.331583        NaN
# 1845           15.426083        NaN
# ...                  ...        ...
# 2009           17.012000  17.056625
# 2010           16.748417  17.041050
# 2011           16.518000  16.999417
# 2012           16.474500  16.924800
# 2013           17.857625  17.036346
#
# [173 rows x 2 columns]
# Ciudad: New York
#       AverageTemperature         10
# Year
# 1743            3.264000        NaN
# 1744           11.660375        NaN
# 1745            1.134500        NaN
# 1750           10.071455        NaN
# 1751           10.794625        NaN
# ...                  ...        ...
# 2009           10.141833  10.598925
# 2010           11.357583  10.737775
# 2011           11.272250  10.771900
# 2012           11.971500  10.843833
# 2013           12.163889  11.076622
#
# [266 rows x 2 columns]
# Ciudad: New Delhi
#       AverageTemperature         10
# Year
# 1796           25.030250        NaN
# 1797           26.711900        NaN
# 1798           24.289700        NaN
# 1799           25.284167        NaN
# 1800           25.207333        NaN
# ...                  ...        ...
# 2009           26.554250  26.096350
# 2010           26.520250  26.143542
# 2011           25.629500  26.120200
# 2012           25.889417  26.045708
# 2013           26.709250  26.144525
#
# [201 rows x 2 columns]
# Ciudad: Sydney
#       AverageTemperature         10
# Year
# 1841           16.564667        NaN
# 1842           16.574917        NaN
# 1843           16.878583        NaN
# 1844           16.218917        NaN
# 1845           16.643500        NaN
# ...                  ...        ...
# 2009           18.175833  17.791308
# 2010           17.999000  17.834467
# 2011           17.713333  17.820350
# 2012           17.474333  17.794400
# 2013           18.089750  17.844142
#
# [173 rows x 2 columns]

# %%
import statsmodels.api as sm

# %%
tempData = data.loc[data.City == 'Mexico']
tempData['Year'] = pd.DatetimeIndex(tempData['dt']).year
graphData = tempData.groupby('Year')['AverageTemperature'].mean().reset_index()
gD2 = graphData.copy()
graphData.set_index('Year', inplace = True)

graphData
# Out:
#       AverageTemperature
# Year
# 1835           14.098083
# 1836           14.803000
# 1837           14.822583
# 1838           14.480333
# 1839           14.907333
# ...                  ...
# 2009           16.653667
# 2010           15.873083
# 2011           16.639167
# 2012           16.426500
# 2013           17.342444
#
# [179 rows x 1 columns]

# %%
descomp1 = sm.tsa.seasonal_decompose(graphData, period = 10)
descomp1.plot()

# %%
# Construct the model
mod = sm.tsa.SARIMAX(gD2['AverageTemperature'], gD2.Year, order=(1, 0, 0), trend='c')
# Estimate the parameters
res = mod.fit()

print(res.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:     AverageTemperature   No. Observations:                  179
# Model:               SARIMAX(1, 0, 0)   Log Likelihood                 -42.298
# Date:                Mon, 07 Nov 2022   AIC                             92.595
# Time:                        09:09:29   BIC                            105.345
# Sample:                             0   HQIC                            97.765
#                                 - 179
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0076      0.703      0.011      0.991      -1.370       1.385
# Year           0.0082      0.001     14.175      0.000       0.007       0.009
# ar.L1          0.3661      0.073      4.991      0.000       0.222       0.510
# sigma2         0.0903      0.009      9.760      0.000       0.072       0.108
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.77   Jarque-Bera (JB):                 0.31
# Prob(Q):                              0.38   Prob(JB):                         0.85
# Heteroskedasticity (H):               1.29   Skew:                             0.10
# Prob(H) (two-sided):                  0.33   Kurtosis:                         3.03
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
res.forecast(steps = 20, exog = list(range(2013, 2033)))
# Out:
# 179    16.767387
# 180    16.565021
# 181    16.496107
# 182    16.476051
# 183    16.473880
# 184    16.478257
# 185    16.485031
# 186    16.492683
# 187    16.500656
# 188    16.508746
# 189    16.516880
# 190    16.525030
# 191    16.533185
# 192    16.541342
# 193    16.549500
# 194    16.557659
# 195    16.565817
# 196    16.573976
# 197    16.582134
# 198    16.590293
# Name: predicted_mean, dtype: float64

# %%
exoList = list(range(2013, 2033))
fc1 = res.get_forecast(steps = 20, exog = exoList)
newData = pd.DataFrame(fc1.summary_frame())
newData['index'] = exoList
newData = newData.set_index('index')
newData
# Out:
# AverageTemperature       mean   mean_se  mean_ci_lower  mean_ci_upper
# index
# 2013                16.767387  0.300565      16.178291      17.356482
# 2014                16.565021  0.320073      15.937689      17.192352
# 2015                16.496107  0.322598      15.863827      17.128388
# 2016                16.476051  0.322935      15.843110      17.108991
# 2017                16.473880  0.322980      15.840851      17.106909
# 2018                16.478257  0.322986      15.845216      17.111298
# 2019                16.485031  0.322987      15.851988      17.118073
# 2020                16.492683  0.322987      15.859640      17.125725
# 2021                16.500656  0.322987      15.867613      17.133698
# 2022                16.508746  0.322987      15.875704      17.141789
# 2023                16.516880  0.322987      15.883837      17.149923
# 2024                16.525030  0.322987      15.891987      17.158072
# 2025                16.533185  0.322987      15.900142      17.166228
# 2026                16.541342  0.322987      15.908300      17.174385
# 2027                16.549500  0.322987      15.916458      17.182543
# 2028                16.557659  0.322987      15.924616      17.190702
# 2029                16.565817  0.322987      15.932775      17.198860
# 2030                16.573976  0.322987      15.940933      17.207019
# 2031                16.582134  0.322987      15.949092      17.215177
# 2032                16.590293  0.322987      15.957250      17.223336

# %%
fig, ax = plt.subplots(figsize=(15, 5))

graphData.plot(ax = ax)
newData['mean'].plot(ax=ax, style='k--')
ax.fill_between(newData.index, newData['mean_ci_lower'], newData['mean_ci_upper'], color='k', alpha=0.1)

# %% [markdown]
# #### Cambio de Temperatura en Temporada

# %%
seasonList = data.Season.unique().tolist()

for season in seasonList:
    tempData = data.loc[data.Season == season]
    tempData['Year'] = pd.DatetimeIndex(tempData['dt']).year
    graphData = tempData.groupby('Year')['AverageTemperature'].mean().reset_index()
    temperature_px = graphData['AverageTemperature']
    graphData['10'] = temperature_px.rolling(window=10).mean()

    graphData.set_index('Year', inplace = True)

    print(f'Temporada: {season}')

    display(graphData)

    plt.figure(figsize=(18,10))
    ax = plt.subplot()
    ax.plot(graphData['AverageTemperature'], alpha=0.8, label='average temperature')
    ax.plot(graphData['10'], color="orange", label='10-year average temperature')
    plt.xlabel('Years')
    plt.ylabel('Temperature (in °C)')
    plt.title(f'Temperatura por año en {season}', fontsize = 20)
    plt.grid()
    plt.legend()
    plt.show()
    plt.clf()
# Out:
# Temporada: Invierno
#       AverageTemperature         10
# Year
# 1745           -1.707308        NaN
# 1750            0.470128        NaN
# 1751           -0.902051        NaN
# 1752           -0.584846        NaN
# 1753            0.142857        NaN
# ...                  ...        ...
# 2009           14.512267  14.257517
# 2010           14.462287  14.324614
# 2011           13.718637  14.280328
# 2012           13.713500  14.152464
# 2013           13.721142  14.126859
#
# [265 rows x 2 columns]
# Temporada: Primavera
#       AverageTemperature         10
# Year
# 1744           12.690897        NaN
# 1745            6.661462        NaN
# 1750           12.545154        NaN
# 1751           12.303000        NaN
# 1752            6.882923        NaN
# ...                  ...        ...
# 2009           23.099050  22.925186
# 2010           23.094180  22.942222
# 2011           22.794727  22.940435
# 2012           23.241177  22.970694
# 2013           23.055374  22.982722
#
# [266 rows x 2 columns]
# Temporada: Verano
#       AverageTemperature         10
# Year
# 1744           16.730500        NaN
# 1750           18.631590        NaN
# 1751           17.876692        NaN
# 1753           18.429024        NaN
# 1754           18.076619        NaN
# ...                  ...        ...
# 2009           24.960080  24.873994
# 2010           25.290577  24.932390
# 2011           24.868953  24.928675
# 2012           25.042683  24.937268
# 2013           25.325363  24.983006
#
# [264 rows x 2 columns]
# Temporada: Otoño
#       AverageTemperature         10
# Year
# 1743            4.020077        NaN
# 1744            3.739949        NaN
# 1750            2.831308        NaN
# 1752            4.845103        NaN
# 1753            4.138667        NaN
# ...                  ...        ...
# 2009           16.763610  16.759988
# 2010           16.799893  16.779655
# 2011           16.814470  16.777382
# 2012           16.675597  16.791415
# 2013           20.537140  17.171079
#
# [265 rows x 2 columns]
